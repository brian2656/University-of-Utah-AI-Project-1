# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib widget

# %%
path_population = Path("Resources/population(1).csv")
population_df = pd.read_csv(path_population)

# %%
population_df
# Out:
#       Country name  Year  Population  \
# 0      Afghanistan  1950     7480464
# 1      Afghanistan  1951     7571542
# 2      Afghanistan  1952     7667534
# 3      Afghanistan  1953     7764549
# 4      Afghanistan  1954     7864289
# ...            ...   ...         ...
# 18283     Zimbabwe  2017    14751101
# 18284     Zimbabwe  2018    15052191
# 18285     Zimbabwe  2019    15354606
# 18286     Zimbabwe  2020    15669663
# 18287     Zimbabwe  2021    15993525
#
#        Population of children under the age of 1  \
# 0                                       301735.0
# 1                                       299368.0
# 2                                       305393.0
# 3                                       311574.0
# 4                                       317584.0
# ...                                          ...
# 18283                                   464521.0
# 18284                                   466524.0
# 18285                                   468844.0
# 18286                                   470340.0
# 18287                                   472443.0
#
#        Population of children under the age of 5  \
# 0                                        1248282
# 1                                        1246857
# 2                                        1248220
# 3                                        1254725
# 4                                        1267817
# ...                                          ...
# 18283                                    2287404
# 18284                                    2283576
# 18285                                    2281740
# 18286                                    2287105
# 18287                                    2299712
#
#        Population of children under the age of 15  \
# 0                                         3068855
# 1                                         3105444
# 2                                         3145070
# 3                                         3186382
# 4                                         3231060
# ...                                           ...
# 18283                                     6217928
# 18284                                     6291632
# 18285                                     6367398
# 18286                                     6449021
# 18287                                     6540282
#
#        Population under the age of 25  Population aged 15 to 64 years  \
# 0                             4494349                         4198587
# 1                             4552138                         4250002
# 2                             4613604                         4303436
# 3                             4676232                         4356242
# 4                             4741371                         4408474
# ...                               ...                             ...
# 18283                         9224369                         8056253
# 18284                         9385132                         8264833
# 18285                         9543409                         8473475
# 18286                         9709135                         8691594
# 18287                         9882718                         8915328
#
#        Population older than 15 years  Population older than 18 years  ...  \
# 0                             4411609                         3946595  ...
# 1                             4466098                         3993640  ...
# 2                             4522464                         4041439  ...
# 3                             4578167                         4088379  ...
# 4                             4633229                         4136116  ...
# ...                               ...                             ...  ...
# 18283                         8532951                         7476399  ...
# 18284                         8760331                         7689502  ...
# 18285                         8986973                         7909270  ...
# 18286                         9220402                         8139472  ...
# 18287                         9453006                         8371027  ...
#
#        population__all__50_54__records  population__all__55_59__records  \
# 0                               255563                           211607
# 1                               256915                           211966
# 2                               258952                           211946
# 3                               261238                           211731
# 4                               263301                           211816
# ...                                ...                              ...
# 18283                           304660                           266109
# 18284                           320980                           264549
# 18285                           341030                           265236
# 18286                           363178                           268363
# 18287                           385387                           273273
#
#        population__all__60_64__records  population__all__65_69__records  \
# 0                               161196                           110709
# 1                               161821                           111465
# 2                               162710                           112142
# 3                               163777                           112800
# 4                               164736                           113474
# ...                                ...                              ...
# 18283                           260767                           207008
# 18284                           258302                           217912
# 18285                           254977                           224850
# 18286                           250478                           226029
# 18287                           244132                           224123
#
#        population__all__70_74__records  population__all__75_79__records  \
# 0                                64310                            28381
# 1                                65210                            29148
# 2                                66123                            29903
# 3                                67058                            30647
# 4                                67953                            31345
# ...                                ...                              ...
# 18283                           128210                            72717
# 18284                           131756                            76831
# 18285                           137699                            81064
# 18286                           146547                            85057
# 18287                           153781                            88180
#
#        population__all__80_84__records  population__all__85_89__records  \
# 0                                 8153                             1346
# 1                                 8672                             1483
# 2                                 9137                             1584
# 3                                 9561                             1693
# 4                                 9963                             1830
# ...                                ...                              ...
# 18283                            38708                            21081
# 18284                            39082                            20618
# 18285                            40180                            20159
# 18286                            41839                            19707
# 18287                            43258                            18969
#
#        population__all__90_94__records  population__all__95_99__records
# 0                                  115                                8
# 1                                  109                                9
# 2                                  129                               10
# 3                                  155                               11
# 4                                  179                               11
# ...                                ...                              ...
# 18283                             7460                             1514
# 18284                             7725                             1574
# 18285                             7895                             1651
# 18286                             7911                             1718
# 18287                             7634                             1733
#
# [18288 rows x 40 columns]

# %%
selected_columns = population_df[["Country name", "Year", "Population"]]
population_only_df = pd.DataFrame(selected_columns)
population_only_df.head()
# Out:
#   Country name  Year  Population
# 0  Afghanistan  1950     7480464
# 1  Afghanistan  1951     7571542
# 2  Afghanistan  1952     7667534
# 3  Afghanistan  1953     7764549
# 4  Afghanistan  1954     7864289

# %%
# Remove all countries except for one
country_name = "Afghanistan"
one_country_df = population_only_df[population_only_df["Country name"] == country_name]
one_country_df.head()
# Out:
#   Country name  Year  Population
# 0  Afghanistan  1950     7480464
# 1  Afghanistan  1951     7571542
# 2  Afghanistan  1952     7667534
# 3  Afghanistan  1953     7764549
# 4  Afghanistan  1954     7864289

# %%
# Slice the DataFrame to include only rows where 'Year' is within the range of 1989 to 2021
one_country_df = one_country_df[(one_country_df['Year'] >= 1989) & (one_country_df['Year'] <= 2021)]
one_country_df
# Out:
#    Country name  Year  Population
# 39  Afghanistan  1989    10673172
# 40  Afghanistan  1990    10694804
# 41  Afghanistan  1991    10745168
# 42  Afghanistan  1992    12057436
# 43  Afghanistan  1993    14003764
# 44  Afghanistan  1994    15455560
# 45  Afghanistan  1995    16418911
# 46  Afghanistan  1996    17106600
# 47  Afghanistan  1997    17788818
# 48  Afghanistan  1998    18493134
# 49  Afghanistan  1999    19262854
# 50  Afghanistan  2000    19542986
# 51  Afghanistan  2001    19688634
# 52  Afghanistan  2002    21000258
# 53  Afghanistan  2003    22645136
# 54  Afghanistan  2004    23553554
# 55  Afghanistan  2005    24411196
# 56  Afghanistan  2006    25442946
# 57  Afghanistan  2007    25903306
# 58  Afghanistan  2008    26427204
# 59  Afghanistan  2009    27385310
# 60  Afghanistan  2010    28189672
# 61  Afghanistan  2011    29249156
# 62  Afghanistan  2012    30466484
# 63  Afghanistan  2013    31541216
# 64  Afghanistan  2014    32716214
# 65  Afghanistan  2015    33753500
# 66  Afghanistan  2016    34636212
# 67  Afghanistan  2017    35643420
# 68  Afghanistan  2018    36686788
# 69  Afghanistan  2019    37769496
# 70  Afghanistan  2020    38972236
# 71  Afghanistan  2021    40099460

# %%
# Reset Index
one_country_df.reset_index(drop=True, inplace=True)
one_country_df.head()
# Out:
#   Country name  Year  Population
# 0  Afghanistan  1989    10673172
# 1  Afghanistan  1990    10694804
# 2  Afghanistan  1991    10745168
# 3  Afghanistan  1992    12057436
# 4  Afghanistan  1993    14003764

# %%
# Drop Country Name and rename df
one_country_df.drop(["Country name"], axis=1, inplace=True)
afg_df = one_country_df
afg_df
# Out:
#     Year  Population
# 0   1989    10673172
# 1   1990    10694804
# 2   1991    10745168
# 3   1992    12057436
# 4   1993    14003764
# 5   1994    15455560
# 6   1995    16418911
# 7   1996    17106600
# 8   1997    17788818
# 9   1998    18493134
# 10  1999    19262854
# 11  2000    19542986
# 12  2001    19688634
# 13  2002    21000258
# 14  2003    22645136
# 15  2004    23553554
# 16  2005    24411196
# 17  2006    25442946
# 18  2007    25903306
# 19  2008    26427204
# 20  2009    27385310
# 21  2010    28189672
# 22  2011    29249156
# 23  2012    30466484
# 24  2013    31541216
# 25  2014    32716214
# 26  2015    33753500
# 27  2016    34636212
# 28  2017    35643420
# 29  2018    36686788
# 30  2019    37769496
# 31  2020    38972236
# 32  2021    40099460

# %%
def millions(x, pos):
    return f"{x*1e-6:1.0f}M"

# %%
# Create graph for lines to go on
fig, ax1 = plt.subplots(figsize=(10, 6))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Plot Population
ax1.plot(afg_df.Year, afg_df.Population, label="Population", color="blue")

# %%
# Format to fit data
ax1.set_ylim(10000000, 41000000)
ax1.yaxis.set_major_formatter(millions)

# %%
# Clean up Graph
ax1.set_xlabel("Year")
ax1.set_ylabel('People')
plt.ylabel('People')
plt.title("Aghanistan: Overall Population 1989-2021")
ax1.grid(True)
